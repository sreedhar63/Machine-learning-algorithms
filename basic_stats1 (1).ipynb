# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sales = pd.read_excel("/content/sales_data_with.xlsx")
sales
# Out:
#           Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0   2021-04-01  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1   2021-04-01  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2   2021-04-01  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3   2021-04-01  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4   2021-04-01  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..         ...       ...  ...  ...     ...        ...    ...         ...
# 445 2021-04-15  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446 2021-04-15  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447 2021-04-15  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448 2021-04-15  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449 2021-04-15  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    datetime64[ns]
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(6)
# memory usage: 45.8+ KB

# %%
sales.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
sales.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
print("avearage % of the sales :",sales['Net Sales Value'].mean())
print("avearage % of the sales :",sales['Discount Rate (%)'].mean())
print("avearage % of the sales :",sales['Total Sales Value'].mean())
# Out:
# avearage % of the sales : 30466.33613127005
# avearage % of the sales : 15.155241895330875
# avearage % of the sales : 33812.83555555555

# %%
print("median of the sales  :",sales['Net Sales Value'].median())
print("median of the sales  :",sales['Discount Rate (%)'].median())
# Out:
# median of the sales  : 4677.78805930185
# median of the sales  : 16.577765649295948

# %%
print("mode of the sales  :",sales['Net Sales Value'].mode())
print("mode of the sales  :",sales['Discount Rate (%)'].mode())
# Out:
# mode of the sales  : 0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# 445    162603.186379
# 446    163915.971000
# 447    163967.080070
# 448    166263.161348
# 449    179507.479049
# Name: Net Sales Value, Length: 450, dtype: float64
# mode of the sales  : 0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64

# %%
print("mode of the model :",sales['Model'].mode())
# Out:
# mode of the model : 0       Babaji Cream
# 1        Babaji Oil
# 2     Babaji Shampoo
# 3      Gear BB Cream
# 4         Gear Cream
# 5           Gear Oil
# 6       Gear Shampoo
# 7          M- Inners
# 8        M- T Shirts
# 9          M-Casuals
# 10         M-Formals
# 11           M-Jeans
# 12           M-Shoes
# 13              O-10
# 14              O-11
# 15             RU-10
# 16              RU-9
# 17         RU-9 Plus
# 18              S-20
# 19              S-21
# 20       Vedic Cream
# 21         Vedic Oil
# 22     Vedic Shampoo
# 23         W-Casuals
# 24          W-Inners
# 25          W-Lounge
# 26         W-Western
# 27            YM-98
# 28             YM-99
# 29        YM-99 Plus
# Name: Model, dtype: object

# %%
plt.plot(sales['Net Sales Value'])
plt.show()

# %%
plt.bar(sales['Net Sales Value'], sales['Brand'])
# Out:
# <BarContainer object of 450 artists>

# %%
plt.hist(sales['Net Sales Value'], bins=10)
plt.show()

# %%
data22 = sales.groupby('Brand')['Net Sales Value'].mean()
data2
# Out:
# Brand
# Babaji       3228.105486
# Gear         1478.756807
# Jeera        4734.729732
# Orange     120665.104341
# RealU       59270.171579
# Sumsang    109806.681809
# Vedic        2081.466600
# Viva         5264.065583
# YouM        67975.870900
# Name: Net Sales Value, dtype: float64

# %%
data2 = sales.loc[:,['Avg Price', 'Total Sales Value', 'Discount Rate (%)',
       'Discount Amount', 'Net Sales Value']]
data2
# Out:
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# 1        10100             101000          11.560498     11676.102961
# 2        16100             112700           9.456886     10657.910157
# 3        20100             120600           6.935385      8364.074702
# 4         8100              24300          17.995663      4372.946230
# ..         ...                ...                ...              ...
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 0      160346.501180
# 1       89323.897039
# 2      102042.089843
# 3      112235.925298
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data2 = scaler.fit_transform(data2)
data2
# Out:
# array([[ 0.091173  ,  2.92572115, -0.83028851,  3.95281631,  2.80475594],
#        [-0.01957016,  1.33099521, -0.85266145,  1.84901409,  1.2710262 ],
#        [ 0.31265934,  1.56277525, -1.35163138,  1.62299458,  1.54567497],
#        ...,
#        [-0.49022863, -0.60644824,  0.90379261, -0.60813967, -0.60192115],
#        [-0.47361715, -0.55692259,  0.38847428, -0.53037877, -0.55549857],
#        [-0.40717125, -0.60842926,  0.04223476, -0.63734468, -0.60123949]])

# %%
print(data2)
# Out:
# [[ 0.091173    2.92572115 -0.83028851  3.95281631  2.80475594]
#  [-0.01957016  1.33099521 -0.85266145  1.84901409  1.2710262 ]
#  [ 0.31265934  1.56277525 -1.35163138  1.62299458  1.54567497]
#  ...
#  [-0.49022863 -0.60644824  0.90379261 -0.60813967 -0.60192115]
#  [-0.47361715 -0.55692259  0.38847428 -0.53037877 -0.55549857]
#  [-0.40717125 -0.60842926  0.04223476 -0.63734468 -0.60123949]]

# %%
import numpy as np
from scipy.stats import zscore


zs = zscore(data2)
outliers = data2[np.abs(zs) > 4]
print("Outliers:", outliers)
# Out:
# Outliers: [4.87952621 4.97049359 4.028995  ]
